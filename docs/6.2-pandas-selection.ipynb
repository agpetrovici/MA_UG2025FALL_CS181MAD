# %% [markdown]
# # Pandas Selection

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. This is the data given as a dictionary

# %%
# Create an example dataframe about a fictional army
raw_data = {
    "regiment": [
        "Nighthawks",
        "Nighthawks",
        "Nighthawks",
        "Nighthawks",
        "Dragoons",
        "Dragoons",
        "Dragoons",
        "Dragoons",
        "Scouts",
        "Scouts",
        "Scouts",
        "Scouts",
    ],
    "company": [
        "1st",
        "1st",
        "2nd",
        "2nd",
        "1st",
        "1st",
        "2nd",
        "2nd",
        "1st",
        "1st",
        "2nd",
        "2nd",
    ],
    "deaths": [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
    "battles": [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
    "size": [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
    "veterans": [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
    "readiness": [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
    "armored": [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
    "deserters": [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
    "origin": [
        "Arizona",
        "California",
        "Texas",
        "Florida",
        "Maine",
        "Iowa",
        "Alaska",
        "Washington",
        "Oregon",
        "Wyoming",
        "Louisana",
        "Georgia",
    ],
}

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.
#
# #### Don't forget to include the columns names in the order presented in the dictionary ('regiment', 'company', 'deaths'...) so that the column index order is consistent with the solutions. If omitted, pandas will order the columns alphabetically.

# %%
army = pd.DataFrame(raw_data)
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# 11      Scouts     2nd      35        9  1523       345          3        1
#
#     deserters      origin
# 0           4     Arizona
# 1          24  California
# 2          31       Texas
# 3           2     Florida
# 4           3       Maine
# 5           4        Iowa
# 6          24      Alaska
# 7          31  Washington
# 8           2      Oregon
# 9           3     Wyoming
# 10          2    Louisana
# 11          3     Georgia

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
army.set_index("origin", inplace=True)
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
army.veterans
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
army[["veterans", "deaths"]]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.loc[["Maine", "Alaska"], ["deaths", "size", "deserters"]]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
index_list = list(army.index)
print(index_list)
index_list[3:7]
# Out:
# ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']
# ['Florida', 'Maine', 'Iowa', 'Alaska']

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %%
army.iloc[3:7, 3:6]
# Out:
#          battles  size  veterans
# origin
# Florida        2  1400        26
# Maine          4  1592        73
# Iowa           7  1006        37
# Alaska         8   987       949

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
army.iloc[4:]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
army.iloc[:4]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
army.iloc[:, 3:7]
# Out:
#             battles  size  veterans  readiness
# origin
# Arizona           5  1045         1          1
# California       42   957         5          2
# Texas             2  1099        62          3
# Florida           2  1400        26          3
# Maine             4  1592        73          2
# Iowa              7  1006        37          1
# Alaska            8   987       949          2
# Washington        3   849        48          3
# Oregon            4   973        48          2
# Wyoming           7  1005       435          1
# Louisana          8  1099        63          2
# Georgia           9  1523       345          3

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
army.deaths > 50
# Out:
# origin
# Arizona        True
# California     True
# Texas         False
# Florida        True
# Maine         False
# Iowa           True
# Alaska         True
# Washington     True
# Oregon         True
# Wyoming        True
# Louisana      False
# Georgia       False
# Name: deaths, dtype: bool

# %%
army[army.deaths > 50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
army.deaths > 500
# Out:
# origin
# Arizona        True
# California    False
# Texas         False
# Florida        True
# Maine         False
# Iowa          False
# Alaska         True
# Washington    False
# Oregon        False
# Wyoming       False
# Louisana      False
# Georgia       False
# Name: deaths, dtype: bool

# %%
army.deaths < 50
# Out:
# origin
# Arizona       False
# California    False
# Texas          True
# Florida       False
# Maine          True
# Iowa          False
# Alaska        False
# Washington    False
# Oregon        False
# Wyoming       False
# Louisana       True
# Georgia        True
# Name: deaths, dtype: bool

# %%
False | True
# Out:
# True

# %%
pd.Series([True, False]) | pd.Series([False, False])
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
army[(army.deaths > 500) | (army.deaths < 50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
army[army.regiment != "Dragoons"]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
army.loc[["Texas", "Arizona"]]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
army.loc["Arizona"]
# Out:
# regiment     Nighthawks
# company             1st
# deaths              523
# battles               5
# size               1045
# veterans              1
# readiness             1
# armored               1
# deserters             4
# Name: Arizona, dtype: object

# %%
army.loc["Arizona"][3]
# Out:
# /tmp/ipykernel_295028/591367592.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   army.loc["Arizona"][3]
# np.int64(5)

# %%
army.loc["Arizona"].iloc[3]
# Out:
# np.int64(5)

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
army.deaths[-3]
# Out:
# /tmp/ipykernel_295028/209010656.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   army.deaths[-3]
# np.int64(73)

# %%
army.deaths.iloc[-3]
# Out:
# np.int64(73)

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %% [markdown]
# ## Sankey diagram
# Let's look at the documentation to make a Sankey Diagram
#
# <https://plotly.com/python/sankey-diagram/>

# %%
import plotly.graph_objects as go

# %%
# Prepare data for Sankey diagram
# We need to create a flow from origin -> regiment -> company

# First, let's look at the data structure
print("Data shape:", army.shape)
print("\nUnique values:")
print("Origins:", army.index.unique())
print("Regiments:", army.regiment.unique())
print("Companies:", army.company.unique())
# Out:
# Data shape: (12, 9)
#
# Unique values:
# Origins: Index(['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska',
#        'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia'],
#       dtype='object', name='origin')
# Regiments: ['Nighthawks' 'Dragoons' 'Scouts']
# Companies: ['1st' '2nd']

# %%
# Create the Sankey diagram data
# We'll create flows: origin -> regiment -> company

# Get all unique values for each level
origins = army.index.unique().tolist()
regiments = army.regiment.unique().tolist()
companies = army.company.unique().tolist()

# Create node labels (all unique values)
all_nodes = origins + regiments + companies

# Create node indices
node_indices = {node: i for i, node in enumerate(all_nodes)}

# Create source and target lists for the flows
sources = []
targets = []
values = []

# Flow 1: Origin -> Regiment
for origin in origins:
    origin_idx = node_indices[origin]
    for regiment in regiments:
        regiment_idx = node_indices[regiment]
        # Sum the army size from this origin in this regiment
        size_sum = army[(army.index == origin) & (army.regiment == regiment)][
            "size"
        ].sum()
        if size_sum > 0:
            sources.append(origin_idx)
            targets.append(regiment_idx)
            values.append(size_sum)

# Flow 2: Regiment -> Company
for regiment in regiments:
    regiment_idx = node_indices[regiment]
    for company in companies:
        company_idx = node_indices[company]
        # Sum the army size from this regiment in this company
        size_sum = army[(army.regiment == regiment) & (army.company == company)][
            "size"
        ].sum()
        if size_sum > 0:
            sources.append(regiment_idx)
            targets.append(company_idx)
            values.append(size_sum)

print(f"Number of nodes: {len(all_nodes)}")
print(f"Number of flows: {len(sources)}")
print(f"Total flow value: {sum(values)}")
# Out:
# Number of nodes: 17
# Number of flows: 18
# Total flow value: 27070

# %%
# Create the Sankey diagram
fig = go.Figure(
    data=[
        go.Sankey(
            node=dict(
                pad=15,
                thickness=20,
                line=dict(color="black", width=0.5),
                label=all_nodes,
                color="lightblue",
            ),
            link=dict(
                source=sources, target=targets, value=values, color="rgba(0,0,255,0.2)"
            ),
        )
    ]
)

fig.update_layout(
    title_text="Army Distribution by Size: Origin → Regiment → Company",
    font_size=12,
    width=1000,
    height=600,
)

fig.show()
